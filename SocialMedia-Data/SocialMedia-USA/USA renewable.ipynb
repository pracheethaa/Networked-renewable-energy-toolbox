# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
import pandas as pd

# URL of the target Facebook page
target_url = "https://www.facebook.com"

# Initialize the Chrome WebDriver
driver = webdriver.Chrome()

# Navigate to Facebook and log in
driver.get(target_url)
username = driver.find_element(By.ID, 'email')
password = driver.find_element(By.ID, 'pass')
username.send_keys('email')  # Replace with your Facebook email
password.send_keys('Password')  # Replace with your Facebook password
password.send_keys(Keys.RETURN)

# Allow some time for the login to complete and CAPTCHA to appear
time.sleep(5)

# Wait for manual CAPTCHA solving
input("Press Enter after solving the CAPTCHA...")

# Navigate to the desired Facebook search page for renewable energy in the USA
driver.get('
           https://www.facebook.com/search/posts/?q=renewable%20energy%20in%20United%20States')

# Allow some time for the page to load
time.sleep(5)

# Initialize empty lists to store the extracted posts and comments
posts = []
comments = []

# Loop to scroll the page and collect posts about renewable energy in the USA
for _ in range(50):  # Adjust the range as necessary to collect more or fewer posts
    # Scroll the page
    driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
    time.sleep(2)  # Adjust sleep time as necessary to allow the page to load

    # Get the page source
    resp = driver.page_source

    # Parse the page source with BeautifulSoup
    soup = BeautifulSoup(resp, 'html.parser')

    # Find the specific divs containing the required post information
    items = soup.find_all('div', {'class': 'x78zum5 xdt5ytf xz62fqu x16ldp7u'})

    # Iterate through each item and extract the desired information
    for item in items:
        post_content = item.get_text()
        if "renewable energy" in post_content.lower() and post_content not in posts:
            posts.append(post_content)
            if len(posts) == 20:  # Stop after collecting 20 posts
                break
    if len(posts) >= 20:
        break

# Function to scroll and scrape comments for a specific post
def scrape_comments():
    # Get the page source
    resp = driver.page_source

    # Parse the page source with BeautifulSoup
    soup = BeautifulSoup(resp, 'html.parser')

    # Find the specific divs containing the comments
    comments_section = soup.find_all('div', {'class': 'xdj266r x11i5rnm xat24cr x1mh8g0r x1vvkbs'})
    post_comments = []
    for comment in comments_section:
        comment_text = comment.get_text()
        if comment_text:
            post_comments.append(comment_text)

    return post_comments

# Loop through the collected posts to scrape comments
for idx, post in enumerate(posts):
    print(f"Post {idx + 1}: {post}")
    
    # Pause the script to allow manual opening of comments
    input("Press Enter after opening the comments for the post...")

    # Scroll and wait for comments to load
    for _ in range(10):
        driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
        time.sleep(2)  # Adjust sleep time as necessary to allow comments to load

    # Scrape comments for the current post
    post_comments = scrape_comments()
    comments.append(post_comments)
    print("Comments collected. You can now close the comments section.")

    # Print comments for the current post
    if post_comments:  # Check if there are comments
        print("Comments:")
        for comment in post_comments:
            print(comment)
    else:
        print("No comments found for this post.")
    
    # Print a message to let you know to close the comments
    input("Press Enter after closing the comments for the post...")

# Prepare data for CSV export
data = []
for idx, content in enumerate(posts):
    if idx < len(comments):  # Ensure there's a comment entry
        for comment in comments[idx]:
            data.append([content, comment])
    else:
        data.append([content, None])

# Create a DataFrame and save it to CSV
df = pd.DataFrame(data, columns=['Post', 'Comment'])
df.to_csv('renewable_energy_usa.csv', index=False)

print("Data has been saved to renewable_energy_usa.csv")
# Out:
# Press Enter after solving the CAPTCHA...
# Post 1: The amount of electricity generated by renewable resources hit a record 28% in April, a breakthrough number that shows how important renewable energy has become in U.S. energy markets.
# Press Enter after opening the comments for the post...
# Comments collected. You can now close the comments section.
# Comments:
# Pipe dream of frivolity right now.
# Good project
# Add
# F
# Add
# Amazing personality with great mentorship features. I try his hands and success follows.  Initially I deposited minimum Capital and I made withdrawal of the amount I wasn't expecting in couple of days. This platform is reliable and can't be overlooked https://www.facebook.com/Alice.katherine.fx.92
# Add
# Could be more easy ... It's quite a bit more here
# A whole 28%. Wow. Let’s all buy EVs and we can take turns charging them. I call Sunday night so I can at least get to work on Mondays. Who wants Tuesday??
# Important?? It shows how forcefully its being shoved down our throats.... There, I fixed for you...
# Ahhh America has never been so reliant on other countries slave labor than ever before! Go USA!!!
# Buuuulllsheeeiiit
# Tommy Moreland it's ok old-timer, we understand your unwillingness to change is stronger than your hope for a healthier planet.
# Press Enter after closing the comments for the post...
# Post 3: The renewable energy sector is now a significant source of jobs, with rapid growth in solar and wind energy employment. In 2022, the United States is North America's largest producer of renewable energy. Germany remains a leader in European renewable energy production, strongly emphasizing wind and solar power.
# Press Enter after opening the comments for the post...
# Comments collected. You can now close the comments section.
# Comments:
# Renewable energy is based on gross generation from wind, geothermal, solar, biomass, and waste, excluding cross-border electricity supply.
# Where did you get those numbers from... Can tell you I have been working in the energy sector for 25 years and for those countries I know they are completly wrong!
# Yes oil is renewable and we have 1000s of years of oil
# Imagine the trillions wasted on this delusion
# biggest producer in America and Europe.... is not the biggest producer in the world....
# I guess nuclear power is included for the US?
# No China strange that.
# Remember 90 percent of all power from Newfoundland & Labrador Canada, Quebec sells to the states, without our hydroelectric power resources they would have very little and would have to rely on nuclear power or other resources. Canada is the biggest resource in the entire world if there were no contracts involved.
# Renewable but not sustainable if one company cuts down trees to build wind energy turbines.
# Now do Asia and show us that all this progress is for nothing until China and India decide to play along.
# Makes no sense at all.
# Norway is #1 in europe in waterpower plants, is that not included in this? 90% of the energy used in Norway is Waterpowerplants?
# No China?  China, today, produces one third of all the renewable energy on the planet.  That didn't happen in the last 2 years!!!!
# So where is Norway? the so called mass EV country…guess the use fossil fuels
# Is this rated output or actual output, which is usually around 25% of rated?
# Hydropower not defined as renewable?
# US 21.5 % of electricity generation from "renewables" in 2023.  Wind alone was over 10%.   Solar in the US will probably pass hydroelectric late this year or sometime in 2025.  It's basically 60% coal+ng, and 40% renewables+nuclear - more NG as coal drops.
# OK, USA is 2 1/2 laps ahead of every one.  Give it a break so the earth can catch up!
# If only the US and Europe were doing their fair share
# How can you renew energy? Did I not pay attention in physics?
# And more to come!The U.S. is only $35trillion in debt. The annual interest is now over $900billion a year - more than military spending.I’m sure that in no way represents just how irresponsible the government can be. There will be more and more and more.
# apparently this is a presentation that omits hydroelectric power
# Bullshit. Solar and wind don't create jobs. They create installs and replacements. That's it. Once done, lots out of work
# Great. Now show as a proportion of total energy production.
# 2003?? Pretty old news
# The size of a country and its population are big factors.  Per capita would make more sense.
# This should be a percentage of national use.
# Norway
# Per capita, i guarantee the US is way way lower than that
# By including the United Kingdom as a whole, you severely reduce the figure. Scotland runs on 99% renewable energy most years, but England does not.
# Türkiye is the best . Advancing faster than any other country on earth.
# At what cost.  Crippling.
# It would have been nice if it was shown in kwh/capita...
# Mexico is going down.
# Whats the unit? The percentage of renewable energy would be more interesting. Like that the figures basically show that big countries produce more and that's not a surprise.
# Waste of energy and money.
# Is it possible to share similar video about renewable Energy producers/ consumption? That would be more useful
# For all the liberal/ndp lovers, there is no such thing as renewable energy yet. All the so called renewable energy takes massive amounts of fossil fuel energy to produce.
# Na wird auch bald das einzige sein das man noch arbeiten kann
# Per capita or percentage of national use figures would be more interesting.
# Show this graph to green party members, who phantasize that the Merkel years were "lost years" for renewable energies.
# All energy originated from the sun and is renewable until the sun dies
# All of Europe buying gas and oil from other countries, useless video
# What a Shitty graph!!! Denmark has No rivers, no Mountains, situatede ind the north of Europe (not that many Sun hours) - But still we are ind the top 5-10 best.
# Why no China
# It would have been more interesting if it were per capita.
# and it's all made in china.. time to wake up.. #FJB the DNC and the green agenda
# More than fake. You forgot hidro power, you Goebbels disciples.
# Would have thought China to be the biggest, despite being the biggest polluters.
# By United Kingdom you mean Scotland not the thieves of Westminster
# and all the global warming freaks still keep losing their minds.............smh
# Germany is full of idiots.  Nice job shutting down all your fission plants.  That should mimimize your carbon footprint.  Mornons.
# Press Enter after closing the comments for the post...
# Post 4: Largest Renewable Energy Producers in Europe and North AmericaIeDcuqKWvAXHD9F2dPrsZe0fzAwYLk5CkWWF96etGzz
# Press Enter after opening the comments for the post...
# Comments collected. You can now close the comments section.
# Comments:
# Renewable energy is based on gross generation from wind, geothermal, solar, biomass, and waste, excluding cross-border electricity supply.
# Where did you get those numbers from... Can tell you I have been working in the energy sector for 25 years and for those countries I know they are completly wrong!
# Yes oil is renewable and we have 1000s of years of oil
# Imagine the trillions wasted on this delusion
# biggest producer in America and Europe.... is not the biggest producer in the world....
# I guess nuclear power is included for the US?
# No China strange that.
# Remember 90 percent of all power from Newfoundland & Labrador Canada, Quebec sells to the states, without our hydroelectric power resources they would have very little and would have to rely on nuclear power or other resources. Canada is the biggest resource in the entire world if there were no contracts involved.
# Renewable but not sustainable if one company cuts down trees to build wind energy turbines.
# Now do Asia and show us that all this progress is for nothing until China and India decide to play along.
# Makes no sense at all.
# Norway is #1 in europe in waterpower plants, is that not included in this? 90% of the energy used in Norway is Waterpowerplants?
# No China?  China, today, produces one third of all the renewable energy on the planet.  That didn't happen in the last 2 years!!!!
# So where is Norway? the so called mass EV country…guess the use fossil fuels
# Is this rated output or actual output, which is usually around 25% of rated?
# Hydropower not defined as renewable?
# US 21.5 % of electricity generation from "renewables" in 2023.  Wind alone was over 10%.   Solar in the US will probably pass hydroelectric late this year or sometime in 2025.  It's basically 60% coal+ng, and 40% renewables+nuclear - more NG as coal drops.
# OK, USA is 2 1/2 laps ahead of every one.  Give it a break so the earth can catch up!
# If only the US and Europe were doing their fair share
# How can you renew energy? Did I not pay attention in physics?
# And more to come!The U.S. is only $35trillion in debt. The annual interest is now over $900billion a year - more than military spending.I’m sure that in no way represents just how irresponsible the government can be. There will be more and more and more.
# apparently this is a presentation that omits hydroelectric power
# Bullshit. Solar and wind don't create jobs. They create installs and replacements. That's it. Once done, lots out of work
# Great. Now show as a proportion of total energy production.
# 2003?? Pretty old news
# The size of a country and its population are big factors.  Per capita would make more sense.
# This should be a percentage of national use.
# Norway
# Per capita, i guarantee the US is way way lower than that
# By including the United Kingdom as a whole, you severely reduce the figure. Scotland runs on 99% renewable energy most years, but England does not.

# Press Enter after opening the comments for the post...
# Comments collected. You can now close the comments section.
# No comments found for this post.
# Press Enter after closing the comments for the post...
# Post 10: Renewable Energy Shatters Records in the U.S.The U.S. has never had as much wind, solar and hydropower. But experts say it’s not enough to meet future electricity demand
# Press Enter after opening the comments for the post...
# Comments collected. You can now close the comments section.
# Comments:
# This is why, along with solar and wind power, nuclear reactors are a necessary part of of adequately providing for the power grid. I recommend thorium and molten salt reactors.
# It's always going to be a losing battle as long as the population is increasing. Stop people from breeding recklessly, and every other problem becomes manageable. But there's been no effort or interest in forcing people to limit breeding, so things will continue to get worse.
# We will never make less renewable power than we do today.
# Wind solar has a very short lifecycle ...Nuclear is the only answer...modern clean-with no long term waste issues.
# Renewables are good as part of the overall solution. Scalability, cost, geographical and most importantly reliability issues are barriers to their being a cost effective 100% solution for high, 7x24 demand sectors such as heavy industry, cloud data centers and AI.
# The main problem we have now is that storage batteries for evening out the delivery flow of uneven sources like solar and wind is prohibitively expensive. So utility companies are replacing coal plants with natural gas instead of renewables.
# Nuclear
# Change is inevitable in both demand and energy production.
# We could always set about using and wasting less. We don’t need half the stuff we think we do, we don’t need to make so many unnecessary journeys, or use so many power hungry items in our homes. The less stuff we consume, the less energy needed to obtain the raw materials, manufacture it, package it, transport it and finally to dispose of it when we get fed up with it.
# Solar panels are cheap, widely available and seem to far surpassing their original projected lifespan. Looking at 75 years now! For the issue of reducing carbon emissions we need everything. All the renewables and probably nuclear too. The new much smaller reactors are interesting. But solar is so cheap.
# Wind energy sounds great until you learned big corp (ie. Boeing) got the contracts instead of indie American startups! And their huge flawed turbines towers are expensive, killing birds, explode during certain storms...
# Nuclear is the only real solution
# So quit using so much electricity!
# Cool, love the green energy. But we'd like more nuke please.
# Meanwhile, China commissioned 340 new coal plants last year, despite also adding significant renewables based capacity. India is also increasing emissions significantly.So whatever we do locally is unlikely to make a substantive difference in a global scale. But at least we can still feel good about it.
# They're also fracking champions which is great for us because that's where we get most if our LNG from. Which in turn ensures we can keep our lights on.Of course we could have our own fracking revolution providing our own energy security and bringing loads if lovely income selling the surplus. But of course all the bloody snowflakes and eco loonies have put paid to that.
# Nuclear is the only technologically viable solution,  it takes 2~3 MILLION pounds of coal/oil/gas to equal the energy in 1 pound of uranium, its a no-brainer, IIRC we have already mined enough to power the entire world for something like the next 400 years.  People have to get over their irrational fear of nuclear,  for example ~20,000 people died from the Fukushima earthquake and tsunami, not a single person died of radiation, yes it was and still is a contamination disaster because of engineering stupidity, but in spite of that stupidity not a single person has died from radiation.
# The key is to transition away from fossil fuels as quickly as possible. No reasonable person is suggesting we dump all fossil fuels and nuclear overnight.
# Just going off the Headlines, I am going to throw my 2cents in..
# Nuclear.
# New nuclear technology:
# Takes time to ramp up new energy sources, always has, always will
# In the UK energy-efficiency has improved each year, but instead of building sustainable communities and local power networks, it introduces daft ideas like battery-powered transport and Air-Source-Heat-Pumps!We have to live within the constraints of what the planet can provide...
# Unless it continues to shatter records as it will. Maybe when people actual see there is no denying the climate emergency as smoke blankets the continent and extreme weather disasters continue to escalate along with the billions in comets then people will be smarter about usage of available power. The addiction to comfort and convenience and the belief that that is a right and not a privilege is the problem. If it is cold where more clothes. Use less power. If it is hot ….use other methods to cool yourself and use less power. But that is not responsible to expect self sacrifice without 100% acceptance of the emergency. Unfortunately  that is why mandates are needed and that will just incite more division as we move forward in the most divisive time we have ever seen.
# so the infrastructure is still not ready for mandated electric vehicles
# That's why we're building more
# Useless. Nuclear and oil.
# Cut back on oil refining...
# My county just killed a big solar project that had already been approved and was started. My recommendation is to vote out all the Regthuglicans in Porter County Indiana.
# So did you think it was going to happen overnight?
# “The Rhodium Group, an energy modeling firm, estimates the U.S. needs to install between 32 GW and 95 GW of new wind and solar capacity every year through 2035 in order to cut emissions 32 percent to 51 percent compared to 2005 levels.”
# Perhaps demands should not always be met.
# Emissions still rising  it's getting hotter faster
# Those solar wind mills are working great out in the ocean. Lol oh wait!! They killing a lot of sea life. Thanks to their loud noises and vibrations
# follow plz muja 300 followers k zarort hai hlp me
# No kidding
# The noise from solar windmills will give us all cancer and flipper babies.
# It's not "demand". It's just usage. We waste far too much. We could easily reduce energy use by a third w/o serious inconvenience.And a lot of energy use is totally stupid. War, for example. Holiday flights, driving a muscle car 20 km twice a day to stuff our fat faces with fast food. Shall I go on?Houses are 40% bigger than a generation ago, even tho families are smaller. And we are neither healthier nor happier. Go minimalist:: Waste not, want not.
# Nuclear is the only way to go.
# Not even close to being enough.
# It's not enough because it needs more infrastructure
# Records of profit for their owners and exploitation of people’s ignorance.
# Tap on the link below and stand the chance of winning a Tesla or been among my investors earning massively in my bitcoin investment company https://t.me/Elon_Musk_1212
# Press Enter after closing the comments for the post...
# Post 11: Renewable energy demand could triple as electricity consumption surgesExecutives at some of the biggest utilities in the U.S. have warned that failure to meet this demand will jeopardize the nation’s economic growth.
# Press Enter after opening the comments for the post...
# Comments collected. You can now close the comments section.
# Comments:
# Kind of a vicious circle if you use fossil fuel energy to cool down because the planet is getting hotter and by using that fossil fuel to cool down it makes the planet even hotter than it was before...
# Gad Fly That's why you tap solar and wind, free energy just waiting to be harvested.
# Press Enter after closing the comments for the post...
# Post 12: China Daily hosted a special event Wednesday at the United Nations Sustainable Development Media Zone and spoke with experts on renewable energy. Experts said that the world's move toward a renewable energy system is an inevitable trend, and #China and the #US should bolster cooperation in the field of new energy for the benefit of the world.
# Press Enter after opening the comments for the post...
# Comments collected. You can now close the comments section.
# No comments found for this post.
# Press Enter after closing the comments for the post...
# Post 13: US, China should boost cooperation on renewable energyukwTFbItmqTC1gJhpd9p4GLx658lZLMc5qugwhGAE7SUGapL5dzPpjjxe5l
# Press Enter after opening the comments for the post...
# Comments collected. You can now close the comments section.
# No comments found for this post.
# Press Enter after closing the comments for the post...
# Post 14: According to American Clean Power, renewable energy provides 15.5% of electricity in America. As the demand for electricity keeps growing in the United States, using renewable energy helps keep our community running smoothly in a clean and dependable way.
# Press Enter after opening the comments for the post...
# Comments collected. You can now close the comments section.
# No comments found for this post.
# Press Enter after closing the comments for the post...
# Post 15: PriyaAccording to American Clean Power, renewable energy provides 15.5% of electricity in America. As the demand for electricity keeps growing in the United States, using renewable energy helps keep our community running smoothly in a clean and dependable way.
# Press Enter after opening the comments for the post...
# Comments collected. You can now close the comments section.
# No comments found for this post.
# Press Enter after closing the comments for the post...
# Post 16: Enlight Renewable Energy  · Shared with Public
# Press Enter after opening the comments for the post...
# Comments collected. You can now close the comments section.
# No comments found for this post.
# Press Enter after closing the comments for the post...
# Post 17: Renewable Energy World  · Shared with Public
# Press Enter after opening the comments for the post...
# Comments collected. You can now close the comments section.
# No comments found for this post.
# Press Enter after closing the comments for the post...
# Post 18: BIG (renewable) energy Over 91% of the electricity powering our facilities globally comes from renewables. In the U.S., we've invested in solar projects in Texas that help power the production of many facilities where Nestle household favorites are made.See how we're working toward 100% renewable energy by 2025. https://www.nestle.com/.../usa-ganado-solar-project...… See more
# Press Enter after opening the comments for the post...
# Comments collected. You can now close the comments section.
# Comments:
# Hey Nestle's, not sure what you did to your dark chocolate baking chips but they're horrible! Switch them back please.
# The last nestle crunch it was obviously put together by people infect with COVID-19. No brains, and rude and where are the good manners about eating keeping the noise to
# Dear Nestle - Your Crunch bars are delicious but the commercial is beyond awful. Some fool sitting on a conveyer belt because the crunch was so loud he didn't hear the TSA instructions? I know that complaining about a commercial is not high on the list of changing the world to be a better place, but less stupidity would help. Advertise why it's good.
# BRING BACK DIBS!!!
# You add SUGAR TO ALL LATINAMERICAN, AFRICAN AND ASIAN COUNTRIES BUT NOT TO PRODUCTS DIRECTED TO EUROPE. You biggest production plant is in Mexico which experiences ALL THE ENVIRONMENTAL IMPACT OF YOUR RACIST AND CAPITALIST SWEEDISH COMPANY. Mexico is no. 1 in diabetes and obesity. Keep using it’s water for your toxic products and displacing breastfeeding culture.
# And we were embarrassed, but thank you
# I would like to know why they are using deceptive labeling on their products.  Nesquick container says Real Cocoa and No Artificials.  BUT....you use GMO Ingredients...I will never buy your products again.
# Dude, if I was homeless, I still wouldn’t steal baby powder
# They use gmo bioengineering ingredients.  Not good for people
# Thank you for leaving Russ1a and supporting Ukraine
# It's hard to be more corrupt than Nestle.
# #NestleCrunchCooperTea'RiffikBarWNBA
# Supports an animal abuser
# I’m actually really impressed with Nestle
# What idiot thought the crunch candy bar commercial was a good idea?  No one wants to hear someone chewing!
# Bring back Butterfinger bb's!!!
# If you wanna know the truth about Nestlé, click here and then read the comments!
# https://elpoderdelconsumidor.org/.../con-56-de-productos.../
# https://www.tiktok.com/t/ZPRwth4KE/
# Press Enter after closing the comments for the post...
# Post 19: IBEW members are making renewable energy history, building the U.S.'s first plant to have wind, solar and battery storage all at one facility. https://bit.ly/3RKZZAC
# Press Enter after opening the comments for the post...
# Comments collected. You can now close the comments section.
# No comments found for this post.
# Press Enter after closing the comments for the post...
# Post 20: PriyaIBEW members are making renewable energy history, building the U.S.'s first plant to have wind, solar and battery storage all at one facility. https://bit.ly/3RKZZAC
# Press Enter after opening the comments for the post...
# Comments collected. You can now close the comments section.
# Comments:
# Solar and wind have it's place. But when an energy producer requires taxpayers to subsidizes it or tax laws being bent to remain competitive, it's defeating the point. It's kind of like the desiel generators powering EV charging stations. CO2 emissions are literal plant food, and diversity is our strength in the energy arena.
# I'd rather have a nuclear plant built.
# I thought the IBEW was to organize electrical workers. Not push an agenda.
# The oversight committee questioned Heritage foundation on their labor agenda. https://youtu.be/00NJRWnE-EE?si=Gaj58hkgjEQtLv-e
# Man, that barren ground sure look like its good for the environment.
# The right choice ￼
# Are the components that make this facility possible, made in the USA, and by Union workers? Or is this facility only wired together by Union workers, in this case IBEW?
# Just remember, we can't eat solar panels. Using up loads of farmland in this country for that waste
# Awesome...
# Is that vehicle solar powered too?
# Solar has destabilized the electrical market and not eliminated any CO2.  Batteries are very expensive. Wind is expensive and has its issues. The people that know the facts and truth have been silenced but people are figuring it out. ￼￼
# A Renewable Energy Facility near tiny Lexington, Ore. — population about 240 — is the country's first plant to have wind, solar and battery storage all at one facility. They are not connected to grid? Cant seem to find facilty on google maps...
# Solar is not being used correctly and we need to make them here not China
# And what does it contribute to the electric grid???Or what is it powering???You DIDNT SPECIFY
# My heart was broken i never believe i will get my lover back again until i meet Doctor Momoh that brought back my wife in 24hours with a powerful love spell. He is reliable for positive result contact the spell caster for love spell on WhatsApp:+2349055080199You can also link him on his page https://www.facebook.com/Drmomohspellcaster/
# CHINA
# 200 ibew jobs lost and seven ibew gained great job keeping good high paying jobs morons
# Press Enter after closing the comments for the post...
# Data has been saved to renewable_energy_usa.csv
